# %% [markdown]
# # <center>Proyecto 1</center>
# ## <center>Modelación y Simulación</center>
# <center>Javier Anleu Alegría - 17149</center>
#
# <center>Andrea Argüello - 17801</center>

# %% [markdown]
# Previous process

# %%
import simpy
import math

# Variables del problema
M = 12 # num cajas
lambda_0 = 1 # clientes que llegan por hora
lambda_1 = 5 # tiempo despacho de cajero por hora
horas = 24

# %%
# Atributos del proceso
env = simpy.Environment() #inicia simulacion
memoria=simpy.Container(env,capacity=100)
cpu=simpy.Resource(env,capacity=1)
waiting=simpy.Resource(env,capacity=1)

# %%
factorial = lambda x: 1 if x==0 else x*(factorial(x-1))
poissonProcess = lambda k, lam, t: math.exp(-lam*t)*((lam*t)**k)/factorial(k)

# %% [markdown]
# # New process

# %% [markdown]
# ## Librerías

# %%
import random
import numpy as np
import simpy

# %% [markdown]
# # Configuración de parámetros para la simulación
# * `M`**:** Número de cajas en el banco
# * `lambda_0`**:** Parámetro $\lambda$ para la distribución de Poisson
# * `lambda_1`**:** Parámetro $\lambda_1$ para la distribución exponencial

# %%
M = 3
lambda_0 = 1
lambda_1 = 4
horas = 24

# %% [markdown]
# ## Funciones para la generaión de variables aleatorias a partir de números aleatorios

# %% [markdown]
# ### Distribución exponencial por Rejection-Sampling

# %% [markdown]
# **Función inversa de la distribución exponencial**

# %%
exponentialInv = lambda x,l: -np.log(1-x)/l

# %% [markdown]
# **Función para generar una variable perteneciente a la distribución exponencial**

# %%
def expSim():
    x = -1
    while x == -1:
        x_s = random.uniform(0,1)
        u = random.uniform(0,1)
        if u<exponentialInv(x_s,lambda_1)/(lambda_1*exponentialInv(x_s,1)):
            x = exponentialInv(x_s,lambda_1)
    return x

# %% [markdown]
# ### Distribución de Poisson por el Método de Transformada Inversa

# %% [markdown]
# **Función para generar una variable perteneciente a la distribución de Poisson**
#
# El algoritmo de la función está basado en el algoritmo para la generación de variables de Poisson por el método de transformada inversa descrito en: http://www.columbia.edu/~ks20/4404-Sigman/4404-Notes-ITM.pdf

# %%
def poissonSim():
    x = 0
    p = np.exp(-lambda_0)
    s = p
    u = random.uniform(0,1)
    while u>s:
        x += 1
        p = p*(lambda_0/x)
        s += p
    return x

# %% [markdown]
# ## Definición de objetos y funciones para la simulación

# %% [markdown]
# ### Modelo de objetos y métodos

# %% [markdown]
# Clase para la generación de clientes. Esta generación sigue la distribución de Poisson con parámetro $\lambda$ (`lambda_0`).

# %%
class Caja(object):
    def __init__(self, env, number, tiempo_atender): # tiempo_atender: expSim
        self.env = env
        self.numero = number
        self.cajero = simpy.Resource(env, capacity=1)
        self.tiempo_atender = tiempo_atender
        self.cola = 0
    
    def atender(self, cliente):
        yield self.env.timeout(self.tiempo_atender)
        print("Caja %d se tomó %d minutos en atender a %s" % (self.numero, self.tiempo_atender, cliente))
        self.cola -= 1
        
    def aumentarCola(self):
        self.cola += 1
        
        
def cliente(env, nombre, caja): # Siguiente cliente llega al cajero
    arrive = env.now
    print('%7.4f %s: Entra al super' % (arrive, nombre))
    with caja.cajero.request() as req:
        yield req
        caja.aumentarCola()
        print('%7.4f %s: Llega a la cola del cajero %d con cola %d' % (arrive, nombre, caja.numero, caja.cola))
        yield env.process(caja.atender(nombre))
        print('%7.4f %s: Ya fue atendido, sale de la tienda, cola en cajero %d es %d' % (arrive, nombre, caja.numero, caja.cola))
        
def setup(env, tiempo_atender, tiempo_llegada_clientes, num_cajas):
    print("haciendo cajas")
    cajas = [Caja(env, i, tiempo_atender) for i in range(1,num_cajas+1)]
    clientes = 0
    while True:
        yield env.timeout(tiempo_llegada_clientes)
        clientes += 1
        print(clientes)
        env.process(cliente(env, 'Cliente %d' % clientes, cajas[random.randint(0,num_cajas-1)]))

# %%
random.seed(123) # This helps reproducing the results
# Create an environment and start the setup process
env = simpy.Environment()
env.process(setup(env, expSim(), poissonSim(), M))
# Execute!
env.run(until=3000)
# Out:
# haciendo cajas
# 1
#  1.0000 Cliente 1: Entra al super
#  1.0000 Cliente 1: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 1
#  1.0000 Cliente 1: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2
#  2.0000 Cliente 2: Entra al super
#  2.0000 Cliente 2: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2
#  2.0000 Cliente 2: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 3
#  3.0000 Cliente 3: Entra al super
#  3.0000 Cliente 3: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 3
#  3.0000 Cliente 3: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 4
#  4.0000 Cliente 4: Entra al super
#  4.0000 Cliente 4: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 4
#  4.0000 Cliente 4: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 5
#  5.0000 Cliente 5: Entra al super
#  5.0000 Cliente 5: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 5
#  5.0000 Cliente 5: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 6
#  6.0000 Cliente 6: Entra al super
#  6.0000 Cliente 6: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 6
#  6.0000 Cliente 6: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 7
#  7.0000 Cliente 7: Entra al super
#  7.0000 Cliente 7: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 7
#  7.0000 Cliente 7: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 8
#  8.0000 Cliente 8: Entra al super
#  8.0000 Cliente 8: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 8
#  8.0000 Cliente 8: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 9
#  9.0000 Cliente 9: Entra al super
#  9.0000 Cliente 9: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 9
#  9.0000 Cliente 9: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 10
# 10.0000 Cliente 10: Entra al super
# 10.0000 Cliente 10: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 10
# 10.0000 Cliente 10: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 11
# 11.0000 Cliente 11: Entra al super
# 11.0000 Cliente 11: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 11
# 11.0000 Cliente 11: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 12
# 12.0000 Cliente 12: Entra al super
# 12.0000 Cliente 12: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 12
# 12.0000 Cliente 12: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 13
# 13.0000 Cliente 13: Entra al super
# 13.0000 Cliente 13: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 13
# 13.0000 Cliente 13: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 14
# 14.0000 Cliente 14: Entra al super
# 14.0000 Cliente 14: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 14
# 14.0000 Cliente 14: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 15
# 15.0000 Cliente 15: Entra al super
# 15.0000 Cliente 15: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 15
# 15.0000 Cliente 15: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 16
# 16.0000 Cliente 16: Entra al super
# 16.0000 Cliente 16: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 16
# 16.0000 Cliente 16: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 17
# 17.0000 Cliente 17: Entra al super
# 17.0000 Cliente 17: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 17
# 17.0000 Cliente 17: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 18
# 18.0000 Cliente 18: Entra al super
# 18.0000 Cliente 18: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 18
# 18.0000 Cliente 18: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 19
# 19.0000 Cliente 19: Entra al super
# 19.0000 Cliente 19: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 19
# 19.0000 Cliente 19: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 20
# 20.0000 Cliente 20: Entra al super
# 20.0000 Cliente 20: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 20
# 20.0000 Cliente 20: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 21
# 21.0000 Cliente 21: Entra al super
# 21.0000 Cliente 21: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 21
# 21.0000 Cliente 21: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 22
# 22.0000 Cliente 22: Entra al super
# 22.0000 Cliente 22: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 22
# 22.0000 Cliente 22: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 23
# 23.0000 Cliente 23: Entra al super
# 23.0000 Cliente 23: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 23
# 23.0000 Cliente 23: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 24
# 24.0000 Cliente 24: Entra al super
# 24.0000 Cliente 24: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 24
# 24.0000 Cliente 24: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 25
# 25.0000 Cliente 25: Entra al super
# 25.0000 Cliente 25: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 25
# 25.0000 Cliente 25: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 26
# 26.0000 Cliente 26: Entra al super
# 26.0000 Cliente 26: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 26
# 26.0000 Cliente 26: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 27
# 27.0000 Cliente 27: Entra al super
# 27.0000 Cliente 27: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 27
# 27.0000 Cliente 27: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 28
# 28.0000 Cliente 28: Entra al super
# 28.0000 Cliente 28: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 28
# 28.0000 Cliente 28: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 29
# 29.0000 Cliente 29: Entra al super
# 29.0000 Cliente 29: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 29
# 29.0000 Cliente 29: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 30
# 30.0000 Cliente 30: Entra al super
# 30.0000 Cliente 30: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 30
# 30.0000 Cliente 30: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 31
# 31.0000 Cliente 31: Entra al super
# 31.0000 Cliente 31: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 31
# 31.0000 Cliente 31: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 32
# 32.0000 Cliente 32: Entra al super
# 32.0000 Cliente 32: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 32
# 32.0000 Cliente 32: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 33
# 33.0000 Cliente 33: Entra al super
# 33.0000 Cliente 33: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 33
# 33.0000 Cliente 33: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 34
# 34.0000 Cliente 34: Entra al super
# 34.0000 Cliente 34: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 34
# 34.0000 Cliente 34: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 35
# 35.0000 Cliente 35: Entra al super
# 35.0000 Cliente 35: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 35
# 35.0000 Cliente 35: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 36
# 36.0000 Cliente 36: Entra al super
# 36.0000 Cliente 36: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 36
# 36.0000 Cliente 36: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 37
# 37.0000 Cliente 37: Entra al super
# 37.0000 Cliente 37: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 37
# 37.0000 Cliente 37: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 38
# 38.0000 Cliente 38: Entra al super
# 38.0000 Cliente 38: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 38
# 38.0000 Cliente 38: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 39
# 39.0000 Cliente 39: Entra al super
# 39.0000 Cliente 39: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 39
# 39.0000 Cliente 39: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 40
# 40.0000 Cliente 40: Entra al super
# 40.0000 Cliente 40: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 40
# 40.0000 Cliente 40: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 41
# 41.0000 Cliente 41: Entra al super
# 41.0000 Cliente 41: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 41
# 41.0000 Cliente 41: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 42
# 42.0000 Cliente 42: Entra al super
# 42.0000 Cliente 42: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 42
# 42.0000 Cliente 42: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 43
# 43.0000 Cliente 43: Entra al super
# 43.0000 Cliente 43: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 43
# 43.0000 Cliente 43: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 44
# 44.0000 Cliente 44: Entra al super
# 44.0000 Cliente 44: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 44
# 44.0000 Cliente 44: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 45
# 45.0000 Cliente 45: Entra al super
# 45.0000 Cliente 45: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 45
# 45.0000 Cliente 45: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 46
# 46.0000 Cliente 46: Entra al super
# 46.0000 Cliente 46: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 46
# 46.0000 Cliente 46: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 47
# 47.0000 Cliente 47: Entra al super
# 47.0000 Cliente 47: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 47
# 47.0000 Cliente 47: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 48
# 48.0000 Cliente 48: Entra al super
# 48.0000 Cliente 48: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 48
# 48.0000 Cliente 48: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 49
# 49.0000 Cliente 49: Entra al super
# 49.0000 Cliente 49: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 49
# 49.0000 Cliente 49: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 50
# 50.0000 Cliente 50: Entra al super
# 50.0000 Cliente 50: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 50
# 50.0000 Cliente 50: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 51
# 51.0000 Cliente 51: Entra al super
# 51.0000 Cliente 51: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 51
# 51.0000 Cliente 51: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 52
# 52.0000 Cliente 52: Entra al super
# 52.0000 Cliente 52: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 52
# 52.0000 Cliente 52: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 53
# 53.0000 Cliente 53: Entra al super
# 53.0000 Cliente 53: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 53
# 53.0000 Cliente 53: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 54
# 54.0000 Cliente 54: Entra al super
# 54.0000 Cliente 54: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 54
# 54.0000 Cliente 54: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 55
# 55.0000 Cliente 55: Entra al super
# 55.0000 Cliente 55: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 55
# 55.0000 Cliente 55: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 56
# 56.0000 Cliente 56: Entra al super
# 56.0000 Cliente 56: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 56
# 56.0000 Cliente 56: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 57
# 57.0000 Cliente 57: Entra al super
# 57.0000 Cliente 57: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 57
# 57.0000 Cliente 57: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 58
# 58.0000 Cliente 58: Entra al super
# 58.0000 Cliente 58: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 58
# 58.0000 Cliente 58: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 59
# 59.0000 Cliente 59: Entra al super
# 59.0000 Cliente 59: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 59
# 59.0000 Cliente 59: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 60
# 60.0000 Cliente 60: Entra al super
# 60.0000 Cliente 60: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 60
# 60.0000 Cliente 60: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 61
# 61.0000 Cliente 61: Entra al super
# 61.0000 Cliente 61: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 61
# 61.0000 Cliente 61: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 62
# 62.0000 Cliente 62: Entra al super
# 62.0000 Cliente 62: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 62
# 62.0000 Cliente 62: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 63
# 63.0000 Cliente 63: Entra al super
# 63.0000 Cliente 63: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 63
# 63.0000 Cliente 63: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 64
# 64.0000 Cliente 64: Entra al super
# 64.0000 Cliente 64: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 64
# 64.0000 Cliente 64: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 65
# 65.0000 Cliente 65: Entra al super
# 65.0000 Cliente 65: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 65
# 65.0000 Cliente 65: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 66
# 66.0000 Cliente 66: Entra al super
# 66.0000 Cliente 66: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 66
# 66.0000 Cliente 66: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 67
# 67.0000 Cliente 67: Entra al super
# 67.0000 Cliente 67: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 67
# 67.0000 Cliente 67: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 68
# 68.0000 Cliente 68: Entra al super
# 68.0000 Cliente 68: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 68
# 68.0000 Cliente 68: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 69
# 69.0000 Cliente 69: Entra al super
# 69.0000 Cliente 69: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 69
# 69.0000 Cliente 69: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 70
# 70.0000 Cliente 70: Entra al super
# 70.0000 Cliente 70: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 70
# 70.0000 Cliente 70: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 71
# 71.0000 Cliente 71: Entra al super
# 71.0000 Cliente 71: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 71
# 71.0000 Cliente 71: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 72
# 72.0000 Cliente 72: Entra al super
# 72.0000 Cliente 72: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 72
# 72.0000 Cliente 72: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 73
# 73.0000 Cliente 73: Entra al super
# 73.0000 Cliente 73: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 73
# 73.0000 Cliente 73: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 74
# 74.0000 Cliente 74: Entra al super
# 74.0000 Cliente 74: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 74
# 74.0000 Cliente 74: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 75
# 75.0000 Cliente 75: Entra al super
# 75.0000 Cliente 75: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 75
# 75.0000 Cliente 75: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 76
# 76.0000 Cliente 76: Entra al super
# 76.0000 Cliente 76: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 76
# 76.0000 Cliente 76: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 77
# 77.0000 Cliente 77: Entra al super
# 77.0000 Cliente 77: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 77
# 77.0000 Cliente 77: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 78
# 78.0000 Cliente 78: Entra al super
# 78.0000 Cliente 78: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 78
# 78.0000 Cliente 78: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 79
# 79.0000 Cliente 79: Entra al super
# 79.0000 Cliente 79: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 79
# 79.0000 Cliente 79: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 80
# 80.0000 Cliente 80: Entra al super
# 80.0000 Cliente 80: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 80
# 80.0000 Cliente 80: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 81
# 81.0000 Cliente 81: Entra al super
# 81.0000 Cliente 81: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 81
# 81.0000 Cliente 81: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 82
# 82.0000 Cliente 82: Entra al super
# 82.0000 Cliente 82: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 82
# 82.0000 Cliente 82: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 83
# 83.0000 Cliente 83: Entra al super
# 83.0000 Cliente 83: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 83
# 83.0000 Cliente 83: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 84
# 84.0000 Cliente 84: Entra al super
# 84.0000 Cliente 84: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 84
# 84.0000 Cliente 84: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 85
# 85.0000 Cliente 85: Entra al super
# 85.0000 Cliente 85: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 85
# 85.0000 Cliente 85: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 86
# 86.0000 Cliente 86: Entra al super
# 86.0000 Cliente 86: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 86
# 86.0000 Cliente 86: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 87
# 87.0000 Cliente 87: Entra al super
# 87.0000 Cliente 87: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 87
# 87.0000 Cliente 87: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 88
# 88.0000 Cliente 88: Entra al super
# 88.0000 Cliente 88: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 88
# 88.0000 Cliente 88: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 89
# 89.0000 Cliente 89: Entra al super
# 89.0000 Cliente 89: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 89
# 89.0000 Cliente 89: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 90
# 90.0000 Cliente 90: Entra al super
# 90.0000 Cliente 90: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 90
# 90.0000 Cliente 90: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 91
# 91.0000 Cliente 91: Entra al super
# 91.0000 Cliente 91: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 91
# 91.0000 Cliente 91: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 92
# 92.0000 Cliente 92: Entra al super
# 92.0000 Cliente 92: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 92
# 92.0000 Cliente 92: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 93
# 93.0000 Cliente 93: Entra al super
# 93.0000 Cliente 93: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 93
# 93.0000 Cliente 93: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 94
# 94.0000 Cliente 94: Entra al super
# 94.0000 Cliente 94: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 94
# 94.0000 Cliente 94: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 95
# 95.0000 Cliente 95: Entra al super
# 95.0000 Cliente 95: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 95
# 95.0000 Cliente 95: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 96
# 96.0000 Cliente 96: Entra al super
# 96.0000 Cliente 96: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 96
# 96.0000 Cliente 96: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 97
# 97.0000 Cliente 97: Entra al super
# 97.0000 Cliente 97: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 97
# 97.0000 Cliente 97: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 98
# 98.0000 Cliente 98: Entra al super
# 98.0000 Cliente 98: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 98
# 98.0000 Cliente 98: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 99
# 99.0000 Cliente 99: Entra al super
# 99.0000 Cliente 99: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 99
# 99.0000 Cliente 99: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 100
# 100.0000 Cliente 100: Entra al super
# 100.0000 Cliente 100: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 100
# 100.0000 Cliente 100: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 101
# 101.0000 Cliente 101: Entra al super
# 101.0000 Cliente 101: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 101
# 101.0000 Cliente 101: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 102
# 102.0000 Cliente 102: Entra al super
# 102.0000 Cliente 102: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 102
# 102.0000 Cliente 102: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 103
# 103.0000 Cliente 103: Entra al super
# 103.0000 Cliente 103: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 103
# 103.0000 Cliente 103: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 104
# 104.0000 Cliente 104: Entra al super
# 104.0000 Cliente 104: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 104
# 104.0000 Cliente 104: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 105
# 105.0000 Cliente 105: Entra al super
# 105.0000 Cliente 105: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 105
# 105.0000 Cliente 105: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 106
# 106.0000 Cliente 106: Entra al super
# 106.0000 Cliente 106: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 106
# 106.0000 Cliente 106: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 107
# 107.0000 Cliente 107: Entra al super
# 107.0000 Cliente 107: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 107
# 107.0000 Cliente 107: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 108
# 108.0000 Cliente 108: Entra al super
# 108.0000 Cliente 108: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 108
# 108.0000 Cliente 108: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 109
# 109.0000 Cliente 109: Entra al super
# 109.0000 Cliente 109: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 109
# 109.0000 Cliente 109: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 110
# 110.0000 Cliente 110: Entra al super
# 110.0000 Cliente 110: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 110
# 110.0000 Cliente 110: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 111
# 111.0000 Cliente 111: Entra al super
# 111.0000 Cliente 111: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 111
# 111.0000 Cliente 111: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 112
# 112.0000 Cliente 112: Entra al super
# 112.0000 Cliente 112: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 112
# 112.0000 Cliente 112: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 113
# 113.0000 Cliente 113: Entra al super
# 113.0000 Cliente 113: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 113
# 113.0000 Cliente 113: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 114
# 114.0000 Cliente 114: Entra al super
# 114.0000 Cliente 114: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 114
# 114.0000 Cliente 114: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 115
# 115.0000 Cliente 115: Entra al super
# 115.0000 Cliente 115: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 115
# 115.0000 Cliente 115: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 116
# 116.0000 Cliente 116: Entra al super
# 116.0000 Cliente 116: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 116
# 116.0000 Cliente 116: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 117
# 117.0000 Cliente 117: Entra al super
# 117.0000 Cliente 117: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 117
# 117.0000 Cliente 117: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 118
# 118.0000 Cliente 118: Entra al super
# 118.0000 Cliente 118: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 118
# 118.0000 Cliente 118: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 119
# 119.0000 Cliente 119: Entra al super
# 119.0000 Cliente 119: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 119
# 119.0000 Cliente 119: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 120
# 120.0000 Cliente 120: Entra al super
# 120.0000 Cliente 120: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 120
# 120.0000 Cliente 120: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 121
# 121.0000 Cliente 121: Entra al super
# 121.0000 Cliente 121: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 121
# 121.0000 Cliente 121: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 122
# 122.0000 Cliente 122: Entra al super
# 122.0000 Cliente 122: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 122
# 122.0000 Cliente 122: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 123
# 123.0000 Cliente 123: Entra al super
# 123.0000 Cliente 123: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 123
# 123.0000 Cliente 123: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 124
# 124.0000 Cliente 124: Entra al super
# 124.0000 Cliente 124: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 124
# 124.0000 Cliente 124: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 125
# 125.0000 Cliente 125: Entra al super
# 125.0000 Cliente 125: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 125
# 125.0000 Cliente 125: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 126
# 126.0000 Cliente 126: Entra al super
# 126.0000 Cliente 126: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 126
# 126.0000 Cliente 126: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 127
# 127.0000 Cliente 127: Entra al super
# 127.0000 Cliente 127: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 127
# 127.0000 Cliente 127: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 128
# 128.0000 Cliente 128: Entra al super
# 128.0000 Cliente 128: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 128
# 128.0000 Cliente 128: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 129
# 129.0000 Cliente 129: Entra al super
# 129.0000 Cliente 129: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 129
# 129.0000 Cliente 129: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 130
# 130.0000 Cliente 130: Entra al super
# 130.0000 Cliente 130: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 130
# 130.0000 Cliente 130: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 131
# 131.0000 Cliente 131: Entra al super
# 131.0000 Cliente 131: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 131
# 131.0000 Cliente 131: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 132
# 132.0000 Cliente 132: Entra al super
# 132.0000 Cliente 132: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 132
# 132.0000 Cliente 132: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 133
# 133.0000 Cliente 133: Entra al super
# 133.0000 Cliente 133: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 133
# 133.0000 Cliente 133: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 134
# 134.0000 Cliente 134: Entra al super
# 134.0000 Cliente 134: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 134
# 134.0000 Cliente 134: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 135
# 135.0000 Cliente 135: Entra al super
# 135.0000 Cliente 135: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 135
# 135.0000 Cliente 135: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 136
# 136.0000 Cliente 136: Entra al super
# 136.0000 Cliente 136: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 136
# 136.0000 Cliente 136: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 137
# 137.0000 Cliente 137: Entra al super
# 137.0000 Cliente 137: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 137
# 137.0000 Cliente 137: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 138
# 138.0000 Cliente 138: Entra al super
# 138.0000 Cliente 138: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 138
# 138.0000 Cliente 138: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 139
# 139.0000 Cliente 139: Entra al super
# 139.0000 Cliente 139: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 139
# 139.0000 Cliente 139: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 140
# 140.0000 Cliente 140: Entra al super
# 140.0000 Cliente 140: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 140
# 140.0000 Cliente 140: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 141
# 141.0000 Cliente 141: Entra al super
# 141.0000 Cliente 141: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 141
# 141.0000 Cliente 141: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 142
# 142.0000 Cliente 142: Entra al super
# 142.0000 Cliente 142: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 142
# 142.0000 Cliente 142: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 143
# 143.0000 Cliente 143: Entra al super
# 143.0000 Cliente 143: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 143
# 143.0000 Cliente 143: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 144
# 144.0000 Cliente 144: Entra al super
# 144.0000 Cliente 144: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 144
# 144.0000 Cliente 144: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 145
# 145.0000 Cliente 145: Entra al super
# 145.0000 Cliente 145: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 145
# 145.0000 Cliente 145: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 146
# 146.0000 Cliente 146: Entra al super
# 146.0000 Cliente 146: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 146
# 146.0000 Cliente 146: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 147
# 147.0000 Cliente 147: Entra al super
# 147.0000 Cliente 147: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 147
# 147.0000 Cliente 147: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 148
# 148.0000 Cliente 148: Entra al super
# 148.0000 Cliente 148: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 148
# 148.0000 Cliente 148: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 149
# 149.0000 Cliente 149: Entra al super
# 149.0000 Cliente 149: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 149
# 149.0000 Cliente 149: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 150
# 150.0000 Cliente 150: Entra al super
# 150.0000 Cliente 150: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 150
# 150.0000 Cliente 150: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 151
# 151.0000 Cliente 151: Entra al super
# 151.0000 Cliente 151: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 151
# 151.0000 Cliente 151: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 152
# 152.0000 Cliente 152: Entra al super
# 152.0000 Cliente 152: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 152
# 152.0000 Cliente 152: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 153
# 153.0000 Cliente 153: Entra al super
# 153.0000 Cliente 153: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 153
# 153.0000 Cliente 153: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 154
# 154.0000 Cliente 154: Entra al super
# 154.0000 Cliente 154: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 154
# 154.0000 Cliente 154: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 155
# 155.0000 Cliente 155: Entra al super
# 155.0000 Cliente 155: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 155
# 155.0000 Cliente 155: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 156
# 156.0000 Cliente 156: Entra al super
# 156.0000 Cliente 156: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 156
# 156.0000 Cliente 156: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 157
# 157.0000 Cliente 157: Entra al super
# 157.0000 Cliente 157: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 157
# 157.0000 Cliente 157: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 158
# 158.0000 Cliente 158: Entra al super
# 158.0000 Cliente 158: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 158
# 158.0000 Cliente 158: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 159
# 159.0000 Cliente 159: Entra al super
# 159.0000 Cliente 159: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 159
# 159.0000 Cliente 159: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 160
# 160.0000 Cliente 160: Entra al super
# 160.0000 Cliente 160: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 160
# 160.0000 Cliente 160: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 161
# 161.0000 Cliente 161: Entra al super
# 161.0000 Cliente 161: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 161
# 161.0000 Cliente 161: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 162
# 162.0000 Cliente 162: Entra al super
# 162.0000 Cliente 162: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 162
# 162.0000 Cliente 162: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 163
# 163.0000 Cliente 163: Entra al super
# 163.0000 Cliente 163: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 163
# 163.0000 Cliente 163: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 164
# 164.0000 Cliente 164: Entra al super
# 164.0000 Cliente 164: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 164
# 164.0000 Cliente 164: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 165
# 165.0000 Cliente 165: Entra al super
# 165.0000 Cliente 165: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 165
# 165.0000 Cliente 165: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 166
# 166.0000 Cliente 166: Entra al super
# 166.0000 Cliente 166: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 166
# 166.0000 Cliente 166: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 167
# 167.0000 Cliente 167: Entra al super
# 167.0000 Cliente 167: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 167
# 167.0000 Cliente 167: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 168
# 168.0000 Cliente 168: Entra al super
# 168.0000 Cliente 168: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 168
# 168.0000 Cliente 168: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 169
# 169.0000 Cliente 169: Entra al super
# 169.0000 Cliente 169: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 169
# 169.0000 Cliente 169: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 170
# 170.0000 Cliente 170: Entra al super
# 170.0000 Cliente 170: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 170
# 170.0000 Cliente 170: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 171
# 171.0000 Cliente 171: Entra al super
# 171.0000 Cliente 171: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 171
# 171.0000 Cliente 171: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 172
# 172.0000 Cliente 172: Entra al super
# 172.0000 Cliente 172: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 172
# 172.0000 Cliente 172: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 173
# 173.0000 Cliente 173: Entra al super
# 173.0000 Cliente 173: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 173
# 173.0000 Cliente 173: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 174
# 174.0000 Cliente 174: Entra al super
# 174.0000 Cliente 174: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 174
# 174.0000 Cliente 174: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 175
# 175.0000 Cliente 175: Entra al super
# 175.0000 Cliente 175: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 175
# 175.0000 Cliente 175: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 176
# 176.0000 Cliente 176: Entra al super
# 176.0000 Cliente 176: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 176
# 176.0000 Cliente 176: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 177
# 177.0000 Cliente 177: Entra al super
# 177.0000 Cliente 177: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 177
# 177.0000 Cliente 177: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 178
# 178.0000 Cliente 178: Entra al super
# 178.0000 Cliente 178: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 178
# 178.0000 Cliente 178: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 179
# 179.0000 Cliente 179: Entra al super
# 179.0000 Cliente 179: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 179
# 179.0000 Cliente 179: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 180
# 180.0000 Cliente 180: Entra al super
# 180.0000 Cliente 180: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 180
# 180.0000 Cliente 180: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 181
# 181.0000 Cliente 181: Entra al super
# 181.0000 Cliente 181: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 181
# 181.0000 Cliente 181: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 182
# 182.0000 Cliente 182: Entra al super
# 182.0000 Cliente 182: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 182
# 182.0000 Cliente 182: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 183
# 183.0000 Cliente 183: Entra al super
# 183.0000 Cliente 183: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 183
# 183.0000 Cliente 183: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 184
# 184.0000 Cliente 184: Entra al super
# 184.0000 Cliente 184: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 184
# 184.0000 Cliente 184: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 185
# 185.0000 Cliente 185: Entra al super
# 185.0000 Cliente 185: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 185
# 185.0000 Cliente 185: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 186
# 186.0000 Cliente 186: Entra al super
# 186.0000 Cliente 186: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 186
# 186.0000 Cliente 186: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 187
# 187.0000 Cliente 187: Entra al super
# 187.0000 Cliente 187: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 187
# 187.0000 Cliente 187: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 188
# 188.0000 Cliente 188: Entra al super
# 188.0000 Cliente 188: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 188
# 188.0000 Cliente 188: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 189
# 189.0000 Cliente 189: Entra al super
# 189.0000 Cliente 189: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 189
# 189.0000 Cliente 189: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 190
# 190.0000 Cliente 190: Entra al super
# 190.0000 Cliente 190: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 190
# 190.0000 Cliente 190: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 191
# 191.0000 Cliente 191: Entra al super
# 191.0000 Cliente 191: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 191
# 191.0000 Cliente 191: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 192
# 192.0000 Cliente 192: Entra al super
# 192.0000 Cliente 192: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 192
# 192.0000 Cliente 192: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 193
# 193.0000 Cliente 193: Entra al super
# 193.0000 Cliente 193: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 193
# 193.0000 Cliente 193: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 194
# 194.0000 Cliente 194: Entra al super
# 194.0000 Cliente 194: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 194
# 194.0000 Cliente 194: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 195
# 195.0000 Cliente 195: Entra al super
# 195.0000 Cliente 195: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 195
# 195.0000 Cliente 195: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 196
# 196.0000 Cliente 196: Entra al super
# 196.0000 Cliente 196: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 196
# 196.0000 Cliente 196: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 197
# 197.0000 Cliente 197: Entra al super
# 197.0000 Cliente 197: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 197
# 197.0000 Cliente 197: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 198
# 198.0000 Cliente 198: Entra al super
# 198.0000 Cliente 198: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 198
# 198.0000 Cliente 198: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 199
# 199.0000 Cliente 199: Entra al super
# 199.0000 Cliente 199: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 199
# 199.0000 Cliente 199: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 200
# 200.0000 Cliente 200: Entra al super
# 200.0000 Cliente 200: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 200
# 200.0000 Cliente 200: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 201
# 201.0000 Cliente 201: Entra al super
# 201.0000 Cliente 201: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 201
# 201.0000 Cliente 201: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 202
# 202.0000 Cliente 202: Entra al super
# 202.0000 Cliente 202: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 202
# 202.0000 Cliente 202: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 203
# 203.0000 Cliente 203: Entra al super
# 203.0000 Cliente 203: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 203
# 203.0000 Cliente 203: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 204
# 204.0000 Cliente 204: Entra al super
# 204.0000 Cliente 204: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 204
# 204.0000 Cliente 204: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 205
# 205.0000 Cliente 205: Entra al super
# 205.0000 Cliente 205: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 205
# 205.0000 Cliente 205: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 206
# 206.0000 Cliente 206: Entra al super
# 206.0000 Cliente 206: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 206
# 206.0000 Cliente 206: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 207
# 207.0000 Cliente 207: Entra al super
# 207.0000 Cliente 207: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 207
# 207.0000 Cliente 207: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 208
# 208.0000 Cliente 208: Entra al super
# 208.0000 Cliente 208: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 208
# 208.0000 Cliente 208: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 209
# 209.0000 Cliente 209: Entra al super
# 209.0000 Cliente 209: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 209
# 209.0000 Cliente 209: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 210
# 210.0000 Cliente 210: Entra al super
# 210.0000 Cliente 210: Llega a la cola del cajero 1 con cola 1
# ...
# 2933.0000 Cliente 2933: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2934
# 2934.0000 Cliente 2934: Entra al super
# 2934.0000 Cliente 2934: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2934
# 2934.0000 Cliente 2934: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2935
# 2935.0000 Cliente 2935: Entra al super
# 2935.0000 Cliente 2935: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2935
# 2935.0000 Cliente 2935: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2936
# 2936.0000 Cliente 2936: Entra al super
# 2936.0000 Cliente 2936: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2936
# 2936.0000 Cliente 2936: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2937
# 2937.0000 Cliente 2937: Entra al super
# 2937.0000 Cliente 2937: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2937
# 2937.0000 Cliente 2937: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2938
# 2938.0000 Cliente 2938: Entra al super
# 2938.0000 Cliente 2938: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2938
# 2938.0000 Cliente 2938: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2939
# 2939.0000 Cliente 2939: Entra al super
# 2939.0000 Cliente 2939: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2939
# 2939.0000 Cliente 2939: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2940
# 2940.0000 Cliente 2940: Entra al super
# 2940.0000 Cliente 2940: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2940
# 2940.0000 Cliente 2940: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2941
# 2941.0000 Cliente 2941: Entra al super
# 2941.0000 Cliente 2941: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2941
# 2941.0000 Cliente 2941: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2942
# 2942.0000 Cliente 2942: Entra al super
# 2942.0000 Cliente 2942: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2942
# 2942.0000 Cliente 2942: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2943
# 2943.0000 Cliente 2943: Entra al super
# 2943.0000 Cliente 2943: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2943
# 2943.0000 Cliente 2943: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2944
# 2944.0000 Cliente 2944: Entra al super
# 2944.0000 Cliente 2944: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2944
# 2944.0000 Cliente 2944: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2945
# 2945.0000 Cliente 2945: Entra al super
# 2945.0000 Cliente 2945: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2945
# 2945.0000 Cliente 2945: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2946
# 2946.0000 Cliente 2946: Entra al super
# 2946.0000 Cliente 2946: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2946
# 2946.0000 Cliente 2946: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2947
# 2947.0000 Cliente 2947: Entra al super
# 2947.0000 Cliente 2947: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2947
# 2947.0000 Cliente 2947: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2948
# 2948.0000 Cliente 2948: Entra al super
# 2948.0000 Cliente 2948: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2948
# 2948.0000 Cliente 2948: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2949
# 2949.0000 Cliente 2949: Entra al super
# 2949.0000 Cliente 2949: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2949
# 2949.0000 Cliente 2949: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2950
# 2950.0000 Cliente 2950: Entra al super
# 2950.0000 Cliente 2950: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2950
# 2950.0000 Cliente 2950: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2951
# 2951.0000 Cliente 2951: Entra al super
# 2951.0000 Cliente 2951: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2951
# 2951.0000 Cliente 2951: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2952
# 2952.0000 Cliente 2952: Entra al super
# 2952.0000 Cliente 2952: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2952
# 2952.0000 Cliente 2952: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2953
# 2953.0000 Cliente 2953: Entra al super
# 2953.0000 Cliente 2953: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2953
# 2953.0000 Cliente 2953: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2954
# 2954.0000 Cliente 2954: Entra al super
# 2954.0000 Cliente 2954: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2954
# 2954.0000 Cliente 2954: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2955
# 2955.0000 Cliente 2955: Entra al super
# 2955.0000 Cliente 2955: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2955
# 2955.0000 Cliente 2955: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2956
# 2956.0000 Cliente 2956: Entra al super
# 2956.0000 Cliente 2956: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2956
# 2956.0000 Cliente 2956: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2957
# 2957.0000 Cliente 2957: Entra al super
# 2957.0000 Cliente 2957: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2957
# 2957.0000 Cliente 2957: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2958
# 2958.0000 Cliente 2958: Entra al super
# 2958.0000 Cliente 2958: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2958
# 2958.0000 Cliente 2958: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2959
# 2959.0000 Cliente 2959: Entra al super
# 2959.0000 Cliente 2959: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2959
# 2959.0000 Cliente 2959: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2960
# 2960.0000 Cliente 2960: Entra al super
# 2960.0000 Cliente 2960: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2960
# 2960.0000 Cliente 2960: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2961
# 2961.0000 Cliente 2961: Entra al super
# 2961.0000 Cliente 2961: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2961
# 2961.0000 Cliente 2961: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2962
# 2962.0000 Cliente 2962: Entra al super
# 2962.0000 Cliente 2962: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2962
# 2962.0000 Cliente 2962: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2963
# 2963.0000 Cliente 2963: Entra al super
# 2963.0000 Cliente 2963: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2963
# 2963.0000 Cliente 2963: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2964
# 2964.0000 Cliente 2964: Entra al super
# 2964.0000 Cliente 2964: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2964
# 2964.0000 Cliente 2964: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2965
# 2965.0000 Cliente 2965: Entra al super
# 2965.0000 Cliente 2965: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2965
# 2965.0000 Cliente 2965: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2966
# 2966.0000 Cliente 2966: Entra al super
# 2966.0000 Cliente 2966: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2966
# 2966.0000 Cliente 2966: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2967
# 2967.0000 Cliente 2967: Entra al super
# 2967.0000 Cliente 2967: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2967
# 2967.0000 Cliente 2967: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2968
# 2968.0000 Cliente 2968: Entra al super
# 2968.0000 Cliente 2968: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2968
# 2968.0000 Cliente 2968: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2969
# 2969.0000 Cliente 2969: Entra al super
# 2969.0000 Cliente 2969: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2969
# 2969.0000 Cliente 2969: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2970
# 2970.0000 Cliente 2970: Entra al super
# 2970.0000 Cliente 2970: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2970
# 2970.0000 Cliente 2970: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2971
# 2971.0000 Cliente 2971: Entra al super
# 2971.0000 Cliente 2971: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2971
# 2971.0000 Cliente 2971: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2972
# 2972.0000 Cliente 2972: Entra al super
# 2972.0000 Cliente 2972: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2972
# 2972.0000 Cliente 2972: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2973
# 2973.0000 Cliente 2973: Entra al super
# 2973.0000 Cliente 2973: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2973
# 2973.0000 Cliente 2973: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2974
# 2974.0000 Cliente 2974: Entra al super
# 2974.0000 Cliente 2974: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2974
# 2974.0000 Cliente 2974: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2975
# 2975.0000 Cliente 2975: Entra al super
# 2975.0000 Cliente 2975: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2975
# 2975.0000 Cliente 2975: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2976
# 2976.0000 Cliente 2976: Entra al super
# 2976.0000 Cliente 2976: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2976
# 2976.0000 Cliente 2976: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2977
# 2977.0000 Cliente 2977: Entra al super
# 2977.0000 Cliente 2977: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2977
# 2977.0000 Cliente 2977: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2978
# 2978.0000 Cliente 2978: Entra al super
# 2978.0000 Cliente 2978: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2978
# 2978.0000 Cliente 2978: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2979
# 2979.0000 Cliente 2979: Entra al super
# 2979.0000 Cliente 2979: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2979
# 2979.0000 Cliente 2979: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2980
# 2980.0000 Cliente 2980: Entra al super
# 2980.0000 Cliente 2980: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2980
# 2980.0000 Cliente 2980: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2981
# 2981.0000 Cliente 2981: Entra al super
# 2981.0000 Cliente 2981: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2981
# 2981.0000 Cliente 2981: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2982
# 2982.0000 Cliente 2982: Entra al super
# 2982.0000 Cliente 2982: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2982
# 2982.0000 Cliente 2982: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2983
# 2983.0000 Cliente 2983: Entra al super
# 2983.0000 Cliente 2983: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2983
# 2983.0000 Cliente 2983: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2984
# 2984.0000 Cliente 2984: Entra al super
# 2984.0000 Cliente 2984: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2984
# 2984.0000 Cliente 2984: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2985
# 2985.0000 Cliente 2985: Entra al super
# 2985.0000 Cliente 2985: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2985
# 2985.0000 Cliente 2985: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2986
# 2986.0000 Cliente 2986: Entra al super
# 2986.0000 Cliente 2986: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2986
# 2986.0000 Cliente 2986: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2987
# 2987.0000 Cliente 2987: Entra al super
# 2987.0000 Cliente 2987: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2987
# 2987.0000 Cliente 2987: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2988
# 2988.0000 Cliente 2988: Entra al super
# 2988.0000 Cliente 2988: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2988
# 2988.0000 Cliente 2988: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2989
# 2989.0000 Cliente 2989: Entra al super
# 2989.0000 Cliente 2989: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2989
# 2989.0000 Cliente 2989: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2990
# 2990.0000 Cliente 2990: Entra al super
# 2990.0000 Cliente 2990: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2990
# 2990.0000 Cliente 2990: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2991
# 2991.0000 Cliente 2991: Entra al super
# 2991.0000 Cliente 2991: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2991
# 2991.0000 Cliente 2991: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2992
# 2992.0000 Cliente 2992: Entra al super
# 2992.0000 Cliente 2992: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2992
# 2992.0000 Cliente 2992: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2993
# 2993.0000 Cliente 2993: Entra al super
# 2993.0000 Cliente 2993: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2993
# 2993.0000 Cliente 2993: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2994
# 2994.0000 Cliente 2994: Entra al super
# 2994.0000 Cliente 2994: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2994
# 2994.0000 Cliente 2994: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2995
# 2995.0000 Cliente 2995: Entra al super
# 2995.0000 Cliente 2995: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2995
# 2995.0000 Cliente 2995: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2996
# 2996.0000 Cliente 2996: Entra al super
# 2996.0000 Cliente 2996: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2996
# 2996.0000 Cliente 2996: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2997
# 2997.0000 Cliente 2997: Entra al super
# 2997.0000 Cliente 2997: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2997
# 2997.0000 Cliente 2997: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2998
# 2998.0000 Cliente 2998: Entra al super
# 2998.0000 Cliente 2998: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2998
# 2998.0000 Cliente 2998: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0
# 2999
# 2999.0000 Cliente 2999: Entra al super
# 2999.0000 Cliente 2999: Llega a la cola del cajero 1 con cola 1
# Caja 1 se tomó 0 minutos en atender a Cliente 2999
# 2999.0000 Cliente 2999: Ya fue atendido, sale de la tienda, cola en cajero 1 es 0

# %%
def generate(env,number,counters):                   
    for i in range(number):
        c = customer(env,"Customer%02d"%(i,),counters)
        activate(c,c.visit(counters))
        t = 3600/number
        yield hold,self,t

# %%
def NoInSystem(R):                                                  
    """ Total number of customers in the resource R"""
    return (len(R.waitQ)+len(R.activeQ))

# %%
class Customer(Process):
    """ Customer arrives, chooses the shortest queue
        is served and leaves
    """
        
    def visit(self,counters):       
        arrive = now()
        Qlength = [NoInSystem(counters[i]) for i in range(Nc)]      
        print ("%f %s: Here I am. %s"%(now(),self.name,Qlength))
        for i in range(Nc):                                         
            if Qlength[i] == 0 or Qlength[i] == min(Qlength):
                choice = i  # the chosen queue number                
                break
                
        yield request,self,counters[choice]
        wait = now()-arrive
        print ("%f %s: Waited %6.3f"%(now(),self.name,wait))
        tib = expSim()
        yield hold,self,tib
        yield release,self,counters[choice]

        print ("%f %s: Finished"%(now(),self.name))

# %%
def customer(env, name, counter):
    #"""Customer arrives, is served and leaves."""
    arrive = env.now
    print('%7.4f %s: Here I am' % (arrive, name))
    Qlength = [NoInSystem(counters[i]) for i in range(Nc)]      
    print ("%f %s: Here I am. %s"%(now(),name,Qlength))
    
    for i in range(M):                                         
        if Qlength[i] == 0 or Qlength[i] == min(Qlength):
            choice = i  # the chosen queue number                
            break
    
    yield Resource.request,counters[choice]
    wait = now()-arrive
    print ("%f %s: Waited %6.3f"%(now(),name,wait))
    tib = expSim()
    yield hold,env.timeout(tib)
    yield release,counters[choice]

    print ("%f %s: Finished"%(now(),name))

# %%
## Experiment data -------------------------
maxTime = 18000.0 # minutes
theseed = 12345                                           
                                    
## Model/Experiment ------------------------------

random.seed(theseed)
env = simpy.Environment()
kk=[simpy.Resource(env, capacity=1) for i in range(M)]   
proc = env.process(generate(env,number=poissonSim(),counters=kk))
env.run(until=maxTime)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bc98d2934ef2> in generate(env, number, counters)
#       3         c = customer(env,"Customer%02d"%(i,),counters)
# ----> 4         activate(c,c.visit(counters))
#       5         t = 3600/number
#
# NameError: name 'activate' is not defined
#
# The above exception was the direct cause of the following exception:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-32aa28fc8774> in <module>
#       9 kk=[simpy.Resource(env, capacity=1) for i in range(M)]
#      10 proc = env.process(generate(env,number=poissonSim(),counters=kk))
# ---> 11 env.run(until=maxTime)
#
# ~/.local/lib/python3.8/site-packages/simpy/core.py in run(self, until)
#     252         try:
#     253             while True:
# --> 254                 self.step()
#     255         except StopSimulation as exc:
#     256             return exc.args[0]  # == until.value
#
# ~/.local/lib/python3.8/site-packages/simpy/core.py in step(self)
#     204             exc = type(event._value)(*event._value.args)
#     205             exc.__cause__ = event._value
# --> 206             raise exc
#     207
#     208     def run(
#
# NameError: name 'activate' is not defined

# %% [markdown]
# ### INTENTO TRES, LA TERCERA ES LA VENCIDA LITERAL
# WORKS LIKE A CHARM

# %%
class Caja(object):
    def __init__(self, env, number, tiempo_atender): # tiempo_atender: expSim
        self.env = env
        self.numero = number
        self.cajero = simpy.Resource(env, capacity=1000)
        self.tiempo_atender = tiempo_atender
        self.cola = 0
    
    def atender(self, cliente):
        yield self.env.timeout(self.tiempo_atender)
        self.cola -= 1
        
    def aumentarCola(self):
        self.cola += 1

def cliente(env, nombre, cajas):
    shortest = cajas[0]
    for caja in cajas:
        print("\U0001F4B2 Caja %d \U0001F4B2 %s" % (caja.numero, "" if caja.cola==0 else "\U0001F6B6"*caja.cola))
        if caja.cola < shortest.cola:
            shortest = caja
    with shortest.cajero.request() as req:
        yield req
        print("%d: %s empieza cola en caja %d \U0001F551" % (env.now, nombre, shortest.numero))
        yield env.timeout(shortest.tiempo_atender*shortest.cola) # esperamos a que atienda a los que hay enfrente
        shortest.aumentarCola() # Aumentamos la cola hasta este punto porque si no estamos esperando doble
        print("%d: %s Llega al cajero de la caja %d \U0001F4B3" % (env.now, nombre, shortest.numero))
        yield env.process(shortest.atender(nombre)) # esperamos a que nos atienda a nosotros
        print("%d: %s sale de la caja %d \U0001F9FE" % (env.now, nombre, shortest.numero))

envi = simpy.Environment()

def setup(env, tiempo_atender, tiempo_llegada_clientes, num_cajas):
    cajas = [Caja(env, i, tiempo_atender) for i in range(1,num_cajas+1)]
    clientes = 0
    while True:
        clientes += 1
        #print("clientes:", clientes)
        yield env.timeout(tiempo_llegada_clientes)
        print("%d: Cliente %d llega a la tienda \U0001F6D2" % (env.now, clientes))
        env.process(cliente(envi, "Cliente %d" % clientes, cajas))
envi.process(setup(envi, 3, 1, M)) # TODO: cambiar 3 y 1 por expSim y poissonSim
envi.run(until=10)
# Out:
# 1: Cliente 1 llega a la tienda 🛒
# 💲 Caja 1 💲
# 💲 Caja 2 💲
# 💲 Caja 3 💲
# 1: Cliente 1 empieza cola en caja 1 🕑
# 2: Cliente 2 llega a la tienda 🛒
# 💲 Caja 1 💲 🚶
# 💲 Caja 2 💲
# 💲 Caja 3 💲
# 2: Cliente 2 empieza cola en caja 2 🕑
# 3: Cliente 3 llega a la tienda 🛒
# 💲 Caja 1 💲 🚶
# 💲 Caja 2 💲 🚶
# 💲 Caja 3 💲
# 3: Cliente 3 empieza cola en caja 3 🕑
# 4: Cliente 1 Llega al cajero de la caja 1 💳
# 4: Cliente 4 llega a la tienda 🛒
# 💲 Caja 1 💲 🚶
# 💲 Caja 2 💲 🚶
# 💲 Caja 3 💲 🚶
# 4: Cliente 4 empieza cola en caja 1 🕑
# 5: Cliente 2 Llega al cajero de la caja 2 💳
# 5: Cliente 5 llega a la tienda 🛒
# 💲 Caja 1 💲 🚶🚶
# 💲 Caja 2 💲 🚶
# 💲 Caja 3 💲 🚶
# 5: Cliente 5 empieza cola en caja 2 🕑
# 6: Cliente 3 Llega al cajero de la caja 3 💳
# 6: Cliente 6 llega a la tienda 🛒
# 💲 Caja 1 💲 🚶🚶
# 💲 Caja 2 💲 🚶🚶
# 💲 Caja 3 💲 🚶
# 6: Cliente 6 empieza cola en caja 3 🕑
# 7: Cliente 7 llega a la tienda 🛒
# 💲 Caja 1 💲 🚶
# 💲 Caja 2 💲 🚶🚶
# 💲 Caja 3 💲 🚶🚶
# 7: Cliente 1 sale de la caja 1 🧾
# 7: Cliente 7 empieza cola en caja 1 🕑
# 8: Cliente 8 llega a la tienda 🛒
# 💲 Caja 1 💲 🚶🚶
# 💲 Caja 2 💲 🚶
# 💲 Caja 3 💲 🚶🚶
# 8: Cliente 2 sale de la caja 2 🧾
# 8: Cliente 8 empieza cola en caja 2 🕑
# 9: Cliente 9 llega a la tienda 🛒
# 💲 Caja 1 💲 🚶🚶
# 💲 Caja 2 💲 🚶🚶
# 💲 Caja 3 💲 🚶
# 9: Cliente 3 sale de la caja 3 🧾
# 9: Cliente 9 empieza cola en caja 3 🕑
